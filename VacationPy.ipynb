# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path

# Import API key
from api_keys import geoapify_key

# %%
pip install cartopy geoviews pyproj
# Out:
# Collecting cartopy
#   Obtaining dependency information for cartopy from https://files.pythonhosted.org/packages/bb/50/ab5495dcc22587179134cd37e6534212babeda78e86bda311c37c773f086/Cartopy-0.22.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading Cartopy-0.22.0-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Collecting geoviews
#   Obtaining dependency information for geoviews from https://files.pythonhosted.org/packages/cb/df/e56a1f048e6aeda6a163a367a1b308f7053154564d728b53a55df603be23/geoviews-1.11.1-py2.py3-none-any.whl.metadata
#   Downloading geoviews-1.11.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting pyproj
#   Obtaining dependency information for pyproj from https://files.pythonhosted.org/packages/79/95/eb68113c5b5737c342bde1bab92705dabe69c16299c5a122616e50f1fbd6/pyproj-3.6.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading pyproj-3.6.1-cp311-cp311-win_amd64.whl.metadata (31 kB)
# Requirement already satisfied: numpy>=1.21 in c:\users\will\anaconda3\lib\site-packages (from cartopy) (1.24.3)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\will\anaconda3\lib\site-packages (from cartopy) (3.7.2)
# Collecting shapely>=1.7 (from cartopy)
#   Obtaining dependency information for shapely>=1.7 from https://files.pythonhosted.org/packages/29/cd/763817c27e6cb6d04ffd477a5dcdfdd71bc3fb640f5748c9f2c1cd08ba52/shapely-2.0.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading shapely-2.0.3-cp311-cp311-win_amd64.whl.metadata (7.2 kB)
# Requirement already satisfied: packaging>=20 in c:\users\will\anaconda3\lib\site-packages (from cartopy) (23.1)
# Collecting pyshp>=2.1 (from cartopy)
#   Obtaining dependency information for pyshp>=2.1 from https://files.pythonhosted.org/packages/98/2f/68116db5b36b895c0450e3072b8cb6c2fac0359279b182ea97014d3c8ac0/pyshp-2.3.1-py2.py3-none-any.whl.metadata
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl.metadata (55 kB)
#      ---------------------------------------- 0.0/56.0 kB ? eta -:--:--
#      ---------------------------------------- 56.0/56.0 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: bokeh<3.4.0,>=3.2.0 in c:\users\will\anaconda3\lib\site-packages (from geoviews) (3.2.1)
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\will\anaconda3\lib\site-packages (from geoviews) (1.17.1)
# Requirement already satisfied: param in c:\users\will\anaconda3\lib\site-packages (from geoviews) (1.13.0)
# Requirement already satisfied: panel>=1.0.0 in c:\users\will\anaconda3\lib\site-packages (from geoviews) (1.2.3)
# Requirement already satisfied: xyzservices in c:\users\will\anaconda3\lib\site-packages (from geoviews) (2022.9.0)
# Requirement already satisfied: certifi in c:\users\will\anaconda3\lib\site-packages (from pyproj) (2023.11.17)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\will\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (3.1.2)
# Requirement already satisfied: contourpy>=1 in c:\users\will\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (1.0.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\will\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (2.0.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\will\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\will\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\will\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (6.3.2)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\will\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (2.3.0)
# Requirement already satisfied: colorcet in c:\users\will\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\will\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\will\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\will\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\will\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\will\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (2.8.2)
# Requirement already satisfied: markdown in c:\users\will\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\will\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.2.0)
# Requirement already satisfied: linkify-it-py in c:\users\will\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\will\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (0.3.0)
# Requirement already satisfied: requests in c:\users\will\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\will\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.65.0)
# Requirement already satisfied: bleach in c:\users\will\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.1.0)
# Requirement already satisfied: typing-extensions in c:\users\will\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\will\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh<3.4.0,>=3.2.0->geoviews) (2.1.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\will\anaconda3\lib\site-packages (from pandas>=1.2->bokeh<3.4.0,>=3.2.0->geoviews) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\will\anaconda3\lib\site-packages (from pandas>=1.2->bokeh<3.4.0,>=3.2.0->geoviews) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\will\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.4->cartopy) (1.16.0)
# Requirement already satisfied: colorama in c:\users\will\anaconda3\lib\site-packages (from tqdm>=4.48.0->panel>=1.0.0->geoviews) (0.4.6)
# Requirement already satisfied: webencodings in c:\users\will\anaconda3\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\will\anaconda3\lib\site-packages (from colorcet->holoviews>=1.16.0->geoviews) (0.5.0)
# Requirement already satisfied: uc-micro-py in c:\users\will\anaconda3\lib\site-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\will\anaconda3\lib\site-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\will\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\will\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\will\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (1.26.16)
# Downloading Cartopy-0.22.0-cp311-cp311-win_amd64.whl (11.2 MB)
#    ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.2 MB 3.2 MB/s eta 0:00:04
#     --------------------------------------- 0.1/11.2 MB 1.7 MB/s eta 0:00:07
#     --------------------------------------- 0.2/11.2 MB 1.8 MB/s eta 0:00:07
#     --------------------------------------- 0.3/11.2 MB 1.5 MB/s eta 0:00:08
#    - -------------------------------------- 0.3/11.2 MB 1.6 MB/s eta 0:00:07
#    - -------------------------------------- 0.4/11.2 MB 1.6 MB/s eta 0:00:07
#    - -------------------------------------- 0.4/11.2 MB 1.6 MB/s eta 0:00:07
#    - -------------------------------------- 0.4/11.2 MB 1.6 MB/s eta 0:00:07
#    - -------------------------------------- 0.4/11.2 MB 995.2 kB/s eta 0:00:11
#    - -------------------------------------- 0.5/11.2 MB 1.1 MB/s eta 0:00:10
#    -- ------------------------------------- 0.6/11.2 MB 1.2 MB/s eta 0:00:09
#    -- ------------------------------------- 0.7/11.2 MB 1.3 MB/s eta 0:00:09
#    -- ------------------------------------- 0.7/11.2 MB 1.3 MB/s eta 0:00:09
#    -- ------------------------------------- 0.8/11.2 MB 1.2 MB/s eta 0:00:09
#    -- ------------------------------------- 0.8/11.2 MB 1.2 MB/s eta 0:00:09
#    --- ------------------------------------ 0.9/11.2 MB 1.2 MB/s eta 0:00:09
#    --- ------------------------------------ 0.9/11.2 MB 1.2 MB/s eta 0:00:09
#    --- ------------------------------------ 1.0/11.2 MB 1.2 MB/s eta 0:00:09
#    --- ------------------------------------ 1.0/11.2 MB 1.2 MB/s eta 0:00:09
#    --- ------------------------------------ 1.1/11.2 MB 1.2 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.1/11.2 MB 1.2 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.2/11.2 MB 1.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.2/11.2 MB 1.2 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.3/11.2 MB 1.2 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.3/11.2 MB 1.2 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.4/11.2 MB 1.2 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.4/11.2 MB 1.2 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.5/11.2 MB 1.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.5/11.2 MB 1.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.6/11.2 MB 1.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.6/11.2 MB 1.1 MB/s eta 0:00:09
#    ------ --------------------------------- 1.7/11.2 MB 1.2 MB/s eta 0:00:09
#    ------ --------------------------------- 1.8/11.2 MB 1.2 MB/s eta 0:00:09
#    ------ --------------------------------- 1.8/11.2 MB 1.2 MB/s eta 0:00:09
#    ------ --------------------------------- 1.9/11.2 MB 1.2 MB/s eta 0:00:09
#    ------ --------------------------------- 1.9/11.2 MB 1.2 MB/s eta 0:00:08
#    ------- -------------------------------- 2.0/11.2 MB 1.2 MB/s eta 0:00:08
#    ------- -------------------------------- 2.1/11.2 MB 1.2 MB/s eta 0:00:08
#    ------- -------------------------------- 2.1/11.2 MB 1.2 MB/s eta 0:00:08
#    ------- -------------------------------- 2.2/11.2 MB 1.2 MB/s eta 0:00:08
#    -------- ------------------------------- 2.3/11.2 MB 1.2 MB/s eta 0:00:08
#    -------- ------------------------------- 2.3/11.2 MB 1.2 MB/s eta 0:00:08
#    -------- ------------------------------- 2.4/11.2 MB 1.2 MB/s eta 0:00:08
#    -------- ------------------------------- 2.4/11.2 MB 1.2 MB/s eta 0:00:08
#    -------- ------------------------------- 2.5/11.2 MB 1.2 MB/s eta 0:00:08
#    --------- ------------------------------ 2.6/11.2 MB 1.2 MB/s eta 0:00:08
#    --------- ------------------------------ 2.6/11.2 MB 1.2 MB/s eta 0:00:08
#    --------- ------------------------------ 2.7/11.2 MB 1.2 MB/s eta 0:00:07
#    --------- ------------------------------ 2.8/11.2 MB 1.2 MB/s eta 0:00:07
#    ---------- ----------------------------- 2.8/11.2 MB 1.2 MB/s eta 0:00:07
#    ---------- ----------------------------- 2.9/11.2 MB 1.2 MB/s eta 0:00:07
#    ---------- ----------------------------- 2.9/11.2 MB 1.2 MB/s eta 0:00:07
#    ---------- ----------------------------- 3.0/11.2 MB 1.2 MB/s eta 0:00:07
#    ----------- ---------------------------- 3.1/11.2 MB 1.2 MB/s eta 0:00:07
#    ----------- ---------------------------- 3.1/11.2 MB 1.2 MB/s eta 0:00:07
#    ----------- ---------------------------- 3.2/11.2 MB 1.2 MB/s eta 0:00:07
#    ----------- ---------------------------- 3.2/11.2 MB 1.2 MB/s eta 0:00:07
#    ----------- ---------------------------- 3.3/11.2 MB 1.2 MB/s eta 0:00:07
#    ------------ --------------------------- 3.4/11.2 MB 1.2 MB/s eta 0:00:07
#    ------------ --------------------------- 3.4/11.2 MB 1.2 MB/s eta 0:00:07
#    ------------ --------------------------- 3.5/11.2 MB 1.2 MB/s eta 0:00:07
#    ------------ --------------------------- 3.6/11.2 MB 1.2 MB/s eta 0:00:07
#    ------------ --------------------------- 3.6/11.2 MB 1.2 MB/s eta 0:00:07
#    ------------- -------------------------- 3.7/11.2 MB 1.2 MB/s eta 0:00:06
#    ------------- -------------------------- 3.7/11.2 MB 1.2 MB/s eta 0:00:06
#    ------------- -------------------------- 3.8/11.2 MB 1.2 MB/s eta 0:00:06
#    ------------- -------------------------- 3.9/11.2 MB 1.2 MB/s eta 0:00:06
#    -------------- ------------------------- 3.9/11.2 MB 1.2 MB/s eta 0:00:06
#    -------------- ------------------------- 4.0/11.2 MB 1.2 MB/s eta 0:00:06
#    -------------- ------------------------- 4.1/11.2 MB 1.3 MB/s eta 0:00:06
#    -------------- ------------------------- 4.1/11.2 MB 1.3 MB/s eta 0:00:06
#    -------------- ------------------------- 4.2/11.2 MB 1.3 MB/s eta 0:00:06
#    --------------- ------------------------ 4.2/11.2 MB 1.3 MB/s eta 0:00:06
#    --------------- ------------------------ 4.3/11.2 MB 1.3 MB/s eta 0:00:06
#    --------------- ------------------------ 4.4/11.2 MB 1.3 MB/s eta 0:00:06
#    --------------- ------------------------ 4.4/11.2 MB 1.3 MB/s eta 0:00:06
#    ---------------- ----------------------- 4.5/11.2 MB 1.3 MB/s eta 0:00:06
#    ---------------- ----------------------- 4.5/11.2 MB 1.3 MB/s eta 0:00:06
#    ---------------- ----------------------- 4.6/11.2 MB 1.3 MB/s eta 0:00:06
#    ---------------- ----------------------- 4.6/11.2 MB 1.3 MB/s eta 0:00:06
#    ---------------- ----------------------- 4.6/11.2 MB 1.3 MB/s eta 0:00:06
#    ----------------- ---------------------- 4.8/11.2 MB 1.3 MB/s eta 0:00:06
#    ----------------- ---------------------- 4.8/11.2 MB 1.3 MB/s eta 0:00:06
#    ----------------- ---------------------- 4.9/11.2 MB 1.3 MB/s eta 0:00:06
#    ----------------- ---------------------- 4.9/11.2 MB 1.3 MB/s eta 0:00:05
#    ----------------- ---------------------- 5.0/11.2 MB 1.3 MB/s eta 0:00:05
#    ------------------ --------------------- 5.1/11.2 MB 1.3 MB/s eta 0:00:05
#    ------------------ --------------------- 5.1/11.2 MB 1.3 MB/s eta 0:00:05
#    ------------------ --------------------- 5.2/11.2 MB 1.3 MB/s eta 0:00:05
#    ------------------ --------------------- 5.2/11.2 MB 1.3 MB/s eta 0:00:05
#    ------------------ --------------------- 5.3/11.2 MB 1.3 MB/s eta 0:00:05
#    ------------------- -------------------- 5.4/11.2 MB 1.3 MB/s eta 0:00:05
#    ------------------- -------------------- 5.4/11.2 MB 1.3 MB/s eta 0:00:05
#    ------------------- -------------------- 5.5/11.2 MB 1.3 MB/s eta 0:00:05
#    ------------------- -------------------- 5.6/11.2 MB 1.3 MB/s eta 0:00:05
#    -------------------- ------------------- 5.6/11.2 MB 1.3 MB/s eta 0:00:05
#    -------------------- ------------------- 5.7/11.2 MB 1.3 MB/s eta 0:00:05
#    -------------------- ------------------- 5.7/11.2 MB 1.3 MB/s eta 0:00:05
#    -------------------- ------------------- 5.8/11.2 MB 1.3 MB/s eta 0:00:05
#    --------------------- ------------------ 5.9/11.2 MB 1.3 MB/s eta 0:00:05
#    --------------------- ------------------ 5.9/11.2 MB 1.3 MB/s eta 0:00:05
#    --------------------- ------------------ 6.0/11.2 MB 1.3 MB/s eta 0:00:05
#    --------------------- ------------------ 6.1/11.2 MB 1.3 MB/s eta 0:00:05
#    --------------------- ------------------ 6.1/11.2 MB 1.3 MB/s eta 0:00:04
#    ---------------------- ----------------- 6.2/11.2 MB 1.3 MB/s eta 0:00:04
#    ---------------------- ----------------- 6.2/11.2 MB 1.3 MB/s eta 0:00:04
#    ---------------------- ----------------- 6.3/11.2 MB 1.3 MB/s eta 0:00:04
#    ---------------------- ----------------- 6.4/11.2 MB 1.3 MB/s eta 0:00:04
#    ----------------------- ---------------- 6.4/11.2 MB 1.3 MB/s eta 0:00:04
#    ----------------------- ---------------- 6.5/11.2 MB 1.3 MB/s eta 0:00:04
#    ----------------------- ---------------- 6.6/11.2 MB 1.3 MB/s eta 0:00:04
#    ----------------------- ---------------- 6.6/11.2 MB 1.3 MB/s eta 0:00:04
#    ----------------------- ---------------- 6.7/11.2 MB 1.3 MB/s eta 0:00:04
#    ------------------------ --------------- 6.7/11.2 MB 1.3 MB/s eta 0:00:04
#    ------------------------ --------------- 6.8/11.2 MB 1.3 MB/s eta 0:00:04
#    ------------------------ --------------- 6.9/11.2 MB 1.3 MB/s eta 0:00:04
#    ------------------------ --------------- 6.9/11.2 MB 1.3 MB/s eta 0:00:04
#    ------------------------- -------------- 7.0/11.2 MB 1.3 MB/s eta 0:00:04
#    ------------------------- -------------- 7.0/11.2 MB 1.3 MB/s eta 0:00:04
#    ------------------------- -------------- 7.1/11.2 MB 1.3 MB/s eta 0:00:04
#    ------------------------- -------------- 7.2/11.2 MB 1.3 MB/s eta 0:00:04
#    ------------------------- -------------- 7.2/11.2 MB 1.3 MB/s eta 0:00:04
#    -------------------------- ------------- 7.3/11.2 MB 1.3 MB/s eta 0:00:04
#    -------------------------- ------------- 7.3/11.2 MB 1.3 MB/s eta 0:00:03
#    -------------------------- ------------- 7.4/11.2 MB 1.3 MB/s eta 0:00:03
#    -------------------------- ------------- 7.5/11.2 MB 1.3 MB/s eta 0:00:03
#    --------------------------- ------------ 7.5/11.2 MB 1.3 MB/s eta 0:00:03
#    --------------------------- ------------ 7.6/11.2 MB 1.3 MB/s eta 0:00:03
#    --------------------------- ------------ 7.7/11.2 MB 1.3 MB/s eta 0:00:03
#    --------------------------- ------------ 7.7/11.2 MB 1.3 MB/s eta 0:00:03
#    --------------------------- ------------ 7.8/11.2 MB 1.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 7.8/11.2 MB 1.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 7.9/11.2 MB 1.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 8.0/11.2 MB 1.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 8.0/11.2 MB 1.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 8.1/11.2 MB 1.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 8.1/11.2 MB 1.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 8.2/11.2 MB 1.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 8.3/11.2 MB 1.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 8.3/11.2 MB 1.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 8.4/11.2 MB 1.3 MB/s eta 0:00:03
#    ------------------------------ --------- 8.4/11.2 MB 1.3 MB/s eta 0:00:03
#    ------------------------------ --------- 8.5/11.2 MB 1.3 MB/s eta 0:00:03
#    ------------------------------ --------- 8.6/11.2 MB 1.3 MB/s eta 0:00:03
#    ------------------------------ --------- 8.6/11.2 MB 1.3 MB/s eta 0:00:02
#    ------------------------------- -------- 8.7/11.2 MB 1.3 MB/s eta 0:00:02
#    ------------------------------- -------- 8.7/11.2 MB 1.3 MB/s eta 0:00:02
#    ------------------------------- -------- 8.8/11.2 MB 1.3 MB/s eta 0:00:02
#    ------------------------------- -------- 8.9/11.2 MB 1.3 MB/s eta 0:00:02
#    -------------------------------- ------- 8.9/11.2 MB 1.3 MB/s eta 0:00:02
#    -------------------------------- ------- 9.0/11.2 MB 1.3 MB/s eta 0:00:02
#    -------------------------------- ------- 9.1/11.2 MB 1.3 MB/s eta 0:00:02
#    -------------------------------- ------- 9.1/11.2 MB 1.3 MB/s eta 0:00:02
#    -------------------------------- ------- 9.2/11.2 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 9.2/11.2 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 9.3/11.2 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 9.4/11.2 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 9.4/11.2 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 9.5/11.2 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 9.6/11.2 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 9.6/11.2 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 9.7/11.2 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 9.7/11.2 MB 1.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 9.8/11.2 MB 1.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 9.9/11.2 MB 1.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.9/11.2 MB 1.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.0/11.2 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/11.2 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 10.1/11.2 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 10.2/11.2 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 10.2/11.2 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 10.3/11.2 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 10.3/11.2 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 10.4/11.2 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 10.5/11.2 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 10.5/11.2 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 10.6/11.2 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 10.7/11.2 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 10.7/11.2 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 10.8/11.2 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 10.8/11.2 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  10.9/11.2 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.2 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.2 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  11.1/11.2 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  11.2/11.2 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 11.2/11.2 MB 1.3 MB/s eta 0:00:00
# Downloading geoviews-1.11.1-py2.py3-none-any.whl (512 kB)
#    ---------------------------------------- 0.0/512.5 kB ? eta -:--:--
#    ---- ----------------------------------- 61.4/512.5 kB 1.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 143.4/512.5 kB 1.4 MB/s eta 0:00:01
#    --------------- ------------------------ 204.8/512.5 kB 1.6 MB/s eta 0:00:01
#    --------------------- ------------------ 276.5/512.5 kB 1.6 MB/s eta 0:00:01
#    --------------------------- ------------ 358.4/512.5 kB 1.5 MB/s eta 0:00:01
#    ------------------------------- -------- 409.6/512.5 kB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 481.3/512.5 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 512.5/512.5 kB 1.4 MB/s eta 0:00:00
# Downloading pyproj-3.6.1-cp311-cp311-win_amd64.whl (6.1 MB)
#    ---------------------------------------- 0.0/6.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/6.1 MB 1.7 MB/s eta 0:00:04
#     --------------------------------------- 0.1/6.1 MB 1.8 MB/s eta 0:00:04
#    - -------------------------------------- 0.2/6.1 MB 1.7 MB/s eta 0:00:04
#    - -------------------------------------- 0.3/6.1 MB 1.6 MB/s eta 0:00:04
#    -- ------------------------------------- 0.3/6.1 MB 1.5 MB/s eta 0:00:04
#    -- ------------------------------------- 0.4/6.1 MB 1.4 MB/s eta 0:00:05
#    --- ------------------------------------ 0.5/6.1 MB 1.4 MB/s eta 0:00:04
#    --- ------------------------------------ 0.5/6.1 MB 1.4 MB/s eta 0:00:05
#    --- ------------------------------------ 0.6/6.1 MB 1.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 0.6/6.1 MB 1.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 0.7/6.1 MB 1.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 0.8/6.1 MB 1.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 0.8/6.1 MB 1.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 0.8/6.1 MB 1.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 0.8/6.1 MB 1.4 MB/s eta 0:00:04
#    ------ --------------------------------- 1.0/6.1 MB 1.4 MB/s eta 0:00:04
#    ------ --------------------------------- 1.0/6.1 MB 1.4 MB/s eta 0:00:04
#    ------- -------------------------------- 1.1/6.1 MB 1.4 MB/s eta 0:00:04
#    ------- -------------------------------- 1.2/6.1 MB 1.4 MB/s eta 0:00:04
#    -------- ------------------------------- 1.2/6.1 MB 1.3 MB/s eta 0:00:04
#    -------- ------------------------------- 1.3/6.1 MB 1.3 MB/s eta 0:00:04
#    -------- ------------------------------- 1.4/6.1 MB 1.4 MB/s eta 0:00:04
#    --------- ------------------------------ 1.4/6.1 MB 1.3 MB/s eta 0:00:04
#    --------- ------------------------------ 1.5/6.1 MB 1.3 MB/s eta 0:00:04
#    ---------- ----------------------------- 1.5/6.1 MB 1.3 MB/s eta 0:00:04
#    ---------- ----------------------------- 1.6/6.1 MB 1.3 MB/s eta 0:00:04
#    ---------- ----------------------------- 1.7/6.1 MB 1.3 MB/s eta 0:00:04
#    ----------- ---------------------------- 1.7/6.1 MB 1.3 MB/s eta 0:00:04
#    ----------- ---------------------------- 1.8/6.1 MB 1.3 MB/s eta 0:00:04
#    ------------ --------------------------- 1.8/6.1 MB 1.3 MB/s eta 0:00:04
#    ------------ --------------------------- 1.9/6.1 MB 1.3 MB/s eta 0:00:04
#    ------------ --------------------------- 2.0/6.1 MB 1.3 MB/s eta 0:00:04
#    ------------- -------------------------- 2.0/6.1 MB 1.3 MB/s eta 0:00:04
#    ------------- -------------------------- 2.1/6.1 MB 1.3 MB/s eta 0:00:03
#    -------------- ------------------------- 2.1/6.1 MB 1.3 MB/s eta 0:00:03
#    -------------- ------------------------- 2.2/6.1 MB 1.3 MB/s eta 0:00:03
#    -------------- ------------------------- 2.3/6.1 MB 1.3 MB/s eta 0:00:03
#    --------------- ------------------------ 2.3/6.1 MB 1.3 MB/s eta 0:00:03
#    --------------- ------------------------ 2.4/6.1 MB 1.3 MB/s eta 0:00:03
#    --------------- ------------------------ 2.4/6.1 MB 1.3 MB/s eta 0:00:03
#    ---------------- ----------------------- 2.5/6.1 MB 1.3 MB/s eta 0:00:03
#    ---------------- ----------------------- 2.6/6.1 MB 1.3 MB/s eta 0:00:03
#    ----------------- ---------------------- 2.6/6.1 MB 1.3 MB/s eta 0:00:03
#    ----------------- ---------------------- 2.7/6.1 MB 1.3 MB/s eta 0:00:03
#    ------------------ --------------------- 2.7/6.1 MB 1.3 MB/s eta 0:00:03
#    ------------------ --------------------- 2.8/6.1 MB 1.3 MB/s eta 0:00:03
#    ------------------ --------------------- 2.9/6.1 MB 1.3 MB/s eta 0:00:03
#    ------------------- -------------------- 2.9/6.1 MB 1.3 MB/s eta 0:00:03
#    ------------------- -------------------- 3.0/6.1 MB 1.3 MB/s eta 0:00:03
#    -------------------- ------------------- 3.1/6.1 MB 1.3 MB/s eta 0:00:03
#    -------------------- ------------------- 3.1/6.1 MB 1.3 MB/s eta 0:00:03
#    -------------------- ------------------- 3.2/6.1 MB 1.3 MB/s eta 0:00:03
#    --------------------- ------------------ 3.2/6.1 MB 1.3 MB/s eta 0:00:03
#    --------------------- ------------------ 3.3/6.1 MB 1.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 3.4/6.1 MB 1.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 3.4/6.1 MB 1.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 3.5/6.1 MB 1.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 3.5/6.1 MB 1.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 3.6/6.1 MB 1.3 MB/s eta 0:00:02
#    ------------------------ --------------- 3.7/6.1 MB 1.3 MB/s eta 0:00:02
#    ------------------------ --------------- 3.7/6.1 MB 1.3 MB/s eta 0:00:02
#    ------------------------- -------------- 3.8/6.1 MB 1.3 MB/s eta 0:00:02
#    ------------------------- -------------- 3.9/6.1 MB 1.3 MB/s eta 0:00:02
#    ------------------------- -------------- 3.9/6.1 MB 1.3 MB/s eta 0:00:02
#    -------------------------- ------------- 4.0/6.1 MB 1.3 MB/s eta 0:00:02
#    -------------------------- ------------- 4.1/6.1 MB 1.3 MB/s eta 0:00:02
#    -------------------------- ------------- 4.1/6.1 MB 1.3 MB/s eta 0:00:02
#    -------------------------- ------------- 4.1/6.1 MB 1.3 MB/s eta 0:00:02
#    --------------------------- ------------ 4.2/6.1 MB 1.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 4.3/6.1 MB 1.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 4.3/6.1 MB 1.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 4.4/6.1 MB 1.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 4.4/6.1 MB 1.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 4.5/6.1 MB 1.3 MB/s eta 0:00:02
#    ------------------------------ --------- 4.6/6.1 MB 1.3 MB/s eta 0:00:02
#    ------------------------------ --------- 4.6/6.1 MB 1.3 MB/s eta 0:00:02
#    ------------------------------ --------- 4.7/6.1 MB 1.3 MB/s eta 0:00:02
#    ------------------------------- -------- 4.8/6.1 MB 1.3 MB/s eta 0:00:02
#    ------------------------------- -------- 4.8/6.1 MB 1.3 MB/s eta 0:00:01
#    ------------------------------- -------- 4.9/6.1 MB 1.3 MB/s eta 0:00:01
#    -------------------------------- ------- 4.9/6.1 MB 1.3 MB/s eta 0:00:01
#    -------------------------------- ------- 5.0/6.1 MB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 5.1/6.1 MB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 5.1/6.1 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.2/6.1 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.2/6.1 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.3/6.1 MB 1.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.4/6.1 MB 1.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.4/6.1 MB 1.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.5/6.1 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 5.6/6.1 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 5.6/6.1 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 5.7/6.1 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 5.7/6.1 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 5.8/6.1 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 5.8/6.1 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 5.9/6.1 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  6.0/6.1 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  6.0/6.1 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  6.1/6.1 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 6.1/6.1 MB 1.3 MB/s eta 0:00:00
# Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#    ---------------------------------------- 0.0/46.5 kB ? eta -:--:--
#    ---------------------------------------- 46.5/46.5 kB 2.4 MB/s eta 0:00:00
# Downloading shapely-2.0.3-cp311-cp311-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    - -------------------------------------- 0.1/1.4 MB 1.7 MB/s eta 0:00:01
#    --- ------------------------------------ 0.1/1.4 MB 1.4 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.2/1.4 MB 1.5 MB/s eta 0:00:01
#    ------- -------------------------------- 0.3/1.4 MB 1.4 MB/s eta 0:00:01
#    -------- ------------------------------- 0.3/1.4 MB 1.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.4/1.4 MB 1.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.4/1.4 MB 1.4 MB/s eta 0:00:01
#    ------------- -------------------------- 0.5/1.4 MB 1.3 MB/s eta 0:00:01
#    --------------- ------------------------ 0.6/1.4 MB 1.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.6/1.4 MB 1.4 MB/s eta 0:00:01
#    ------------------- -------------------- 0.7/1.4 MB 1.4 MB/s eta 0:00:01
#    -------------------- ------------------- 0.7/1.4 MB 1.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.8/1.4 MB 1.4 MB/s eta 0:00:01
#    ------------------------ --------------- 0.9/1.4 MB 1.4 MB/s eta 0:00:01
#    -------------------------- ------------- 0.9/1.4 MB 1.4 MB/s eta 0:00:01
#    --------------------------- ------------ 1.0/1.4 MB 1.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.1/1.4 MB 1.4 MB/s eta 0:00:01
#    ------------------------------- -------- 1.1/1.4 MB 1.3 MB/s eta 0:00:01
#    -------------------------------- ------- 1.2/1.4 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.2/1.4 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 1.3/1.4 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 1.4/1.4 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  1.4/1.4 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 1.3 MB/s eta 0:00:00
# Installing collected packages: shapely, pyshp, pyproj, cartopy, geoviews
# Successfully installed cartopy-0.22.0 geoviews-1.11.1 pyproj-3.6.1 pyshp-2.3.1 shapely-2.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("../output_data/cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0           utrik  11.2278  169.8474     27.04        79          59
# 1        1        hermanus -34.4187   19.2345     27.67        49          27
# 2        2         taulaga -11.0553 -171.0883     29.39        75          53
# 3        3             gao  16.6362    1.6370     32.85         6           0
# 4        4  puerto natales -51.7236  -72.4875     -0.23        90          57
#
#    Wind Speed Country        Date
# 0        5.29      MH  1710930612
# 1        5.70      ZA  1710930614
# 2        4.88      AS  1710930615
# 3        6.03      ML  1710930617
# 4        2.38      CL  1710930618

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_map = city_data_df.hvplot.points("Lng", 
                                      "Lat", 
                                      geo = True,
                                      color = "City",
                                      alpha = 0.6,
                                      size = "Humidity",
                                      tiles = "OSM"
                                     )

# Display the map
city_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values

# A max temp lower than 28 and but higher than 19. Cloudiness less than 2

# Drop any rows with null values
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE

weather_filtered_df = city_data_df.loc[(city_data_df["Max Temp"] < 28)
                                       & (city_data_df["Max Temp"] > 19) 
                                       & (city_data_df["Cloudiness"] < 2)
                                       & (city_data_df["Wind Speed"] < 5.5)
                                      ]

# Drop any rows with null values
weather_filtered_df.dropna()

# Display sample data
weather_filtered_df
# Out:
#      City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 118      118         ghadamis  30.1337    9.5007     27.90        13
# 216      216            gafsa  34.4250    8.7842     22.12        43
# 256      256           teknaf  20.8624   92.3058     27.75        57
# 300      300         sultanah  24.4926   39.5857     25.25        19
# 309      309     piti village  13.4626  144.6933     26.28        80
# 362      362    cockburn town  21.4612  -71.1419     25.58        76
# 407      407           saipan  15.1355  145.7010     25.39        73
# 451      451  metlili chaamba  32.2667    3.6333     24.52        18
# 489      489      tamanrasset  22.7850    5.5228     23.95         9
# 505      505       siwa oasis  29.2041   25.5195     25.94        18
#
#      Cloudiness  Wind Speed Country        Date
# 118           0        0.81      LY  1710930804
# 216           0        3.60      TN  1710930966
# 256           0        4.58      BD  1710931025
# 300           0        4.12      SA  1710931093
# 309           0        3.09      GU  1710931106
# 362           0        4.57      TC  1710931161
# 407           0        2.57      MP  1710931021
# 451           0        4.12      DZ  1710931252
# 489           0        2.06      DZ  1710931293
# 505           0        5.33      EG  1710931311

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE
hotel_df = weather_filtered_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE
hotel_df["Hotel Name"] = ""
# Display sample data
# YOUR CODE HERE

hotel_df
# Out:
#                 City Country      Lat       Lng  Humidity Hotel Name
# 118         ghadamis      LY  30.1337    9.5007        13
# 216            gafsa      TN  34.4250    8.7842        43
# 256           teknaf      BD  20.8624   92.3058        57
# 300         sultanah      SA  24.4926   39.5857        19
# 309     piti village      GU  13.4626  144.6933        80
# 362    cockburn town      TC  21.4612  -71.1419        76
# 407           saipan      MP  15.1355  145.7010        73
# 451  metlili chaamba      DZ  32.2667    3.6333        18
# 489      tamanrasset      DZ  22.7850    5.5228         9
# 505       siwa oasis      EG  29.2041   25.5195        18

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {"categories": "accommodation.hotel",
          "apiKey":geoapify_key
         }

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    longitude = row["Lng"]
    latitude = row["Lat"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] =  f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params = params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# ghadamis - nearest hotel: فندق عين الفارس
# gafsa - nearest hotel: Hôtel moussa
# teknaf - nearest hotel: No hotel found
# sultanah - nearest hotel: فندق جلنار
# piti village - nearest hotel: The Cliff Hotel
# cockburn town - nearest hotel: The Salt Raker Inn
# saipan - nearest hotel: Chalan Kanoa Beach Hotel
# metlili chaamba - nearest hotel: No hotel found
# tamanrasset - nearest hotel: فندق الأمان
# siwa oasis - nearest hotel: فندق الكيلانى
#                 City Country      Lat       Lng  Humidity  \
# 118         ghadamis      LY  30.1337    9.5007        13
# 216            gafsa      TN  34.4250    8.7842        43
# 256           teknaf      BD  20.8624   92.3058        57
# 300         sultanah      SA  24.4926   39.5857        19
# 309     piti village      GU  13.4626  144.6933        80
# 362    cockburn town      TC  21.4612  -71.1419        76
# 407           saipan      MP  15.1355  145.7010        73
# 451  metlili chaamba      DZ  32.2667    3.6333        18
# 489      tamanrasset      DZ  22.7850    5.5228         9
# 505       siwa oasis      EG  29.2041   25.5195        18
#
#                    Hotel Name
# 118           فندق عين الفارس
# 216              Hôtel moussa
# 256            No hotel found
# 300                فندق جلنار
# 309           The Cliff Hotel
# 362        The Salt Raker Inn
# 407  Chalan Kanoa Beach Hotel
# 451            No hotel found
# 489               فندق الأمان
# 505             فندق الكيلانى

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE
hotel_map = hotel_df.hvplot.points("Lng", 
                                   "Lat", 
                                   geo = True,
                                   color = "City",
                                   alpha = 0.8,
                                   size = "Humidity",
                                   tiles = "OSM",
                                   hover_cols = ["Hotel Name", "Country"]
                                  )
# Display the map
# YOUR CODE HERE
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
